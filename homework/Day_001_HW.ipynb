# %% [markdown]
# ### 作業1
#
# 1. 你選的這組資料為何重要 Ans:透過車種分類,可過濾在路口監視器中的車種記錄,進而鎖定追查對象的行經路徑,對於治安維護上有很大的幫助
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集) Ans:提供者為Stanford 大學
#
# 3. 蒐集而來的資料型態為何 Ans:圖像(非結構化資料)
#
# 4. 這組資料想解決的問題如何評估 Ans:使用適用於圖像識別的演算法(例如深度學習)訓練分類器,並透過 F-Measure進行分類器的驗証以評估分類器是否有效
#
#
#
# ### 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」) Ans:為了提升業績,需減短車隊工作中的空車的時間,因此需明確了解潛在客戶的所在的時間及地點(統稱為需求點),並在車隊為空車時,前往最近的需求點,假設能建構需求點的大數據資料庫,則可透過讓空閒的車前往最近的需求點駐留而使得載客機率提升及空車時間縮短,則業績即可提升
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集) Ans:車隊建立載客地點記錄數據,欄位包含:地點,時間及每台車的空車時間
#
# 3. 蒐集而來的資料型態為何 Ans:數值、文字 (結構化資料)
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證) Ans:提供需求點數據給車隊後,評估每台車的空車時間的平均是否有縮短,即可驗証方法是否有效

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 222.601
# The Mean absolute error is 12.091
